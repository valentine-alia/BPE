# %%
#Imports
using Plots
using Printf
using DifferentialEquations
using DataFrames
using CSV

# %% [markdown]
# For my ODE, I've chosen a simple model of exponential decay:
# $u' = -au$

# %%
# Read in the data
data = CSV.read("/Users/annarittenhouse/Downloads/anna_ode_challenge_1_data.csv", DataFrame) 

# Unpack data into more readable variables
t = data[!,1]
x = data[!,2]
print()

# %%
# Plot data
plot(t,x, linewidth = 2, title = "Exponential Decay",
     xaxis = "Time ", yaxis = "Population Size")
