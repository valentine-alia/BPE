# %%
import pandas as pd  # Data handling
import matplotlib.pyplot as plt # visualization
from scipy.integrate import odeint # numerical integration
import numpy as np
from pyvbmc import VBMC # VMBC object
import scipy.stats as scs # scipy stats to get distributions from
from pyvbmc.priors import UniformBox, Trapezoidal, SplineTrapezoidal, SmoothBox # nice priors from PyVBMC
import seaborn as sns

# %% [markdown]
# $$x = A\cos(Bt - \delta)$$

# %%
def analytic_sol(t,A,B,delta):
    return A * np.cos(B* t - delta) + sigma * np.random.randn(len(t))

def log_likelihood(theta):
    delta = theta
    sol = analytic_sol(t,A,B,delta)
    return np.sum(np.log(1/(sigma* (2*np.pi)**0.5)) - (0.5/sigma**2) * (sol - x_true)**2)

# %%
t = np.arange(0,10,0.05)
A = 2.0
sigma = 0.1
B = 2.0
delta_true = np.pi / 2
print(delta_true)
x_true = analytic_sol(t,A,B,delta_true)

plt.plot(t,x_true)
plt.show()
# Out:
# 1.5707963267948966

# %%
sols = []
deltas = np.arange(0,2*np.pi*delta_true,0.01)
for delta in deltas:
    sols.append(log_likelihood(delta))
print("best choice for delta_0:",deltas[np.argmax(np.array(sols))])
delta_min = deltas[np.argmin(np.array(sols))]
print("delta that gives log likelihood minimum:",delta_min)
plt.figure(figsize=(9,6))
plt.plot(deltas,sols)
plt.title("Log Likelihood")
#plt.ylim(-30000,1000)
plt.xlabel(r"$\delta$")
plt.ylabel("Log Likelihood")
plt.show()
# Out:
# best choice for delta_0: 7.87
# delta that gives log likelihood minimum: 4.59

# %%
D = 1  

LB = np.full((1, D), 0.0)  # Lower bounds
UB = np.full((1, D), 10.0)  # Upper bounds

PLB = np.copy(LB)
PLB[0][0] = 0.5
PUB = np.copy(UB) 
PUB[0][0] =  9.5


x0 = np.atleast_2d(delta_min)

options = {
    "max_fun_evals": 150
}

prior = SplineTrapezoidal(LB, PLB, PUB, UB)

print("LB:",LB,"PLB:",PLB,"PUB:",PUB,"UB:",UB,'x0:',x0)
# Out:
# LB: [[0.]] PLB: [[0.5]] PUB: [[9.5]] UB: [[10.]] x0: [[4.59]]

# %%
vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior,options = options) # initialize VMBC object

vp, results = vbmc.optimize() # do optimization (might take a while)
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10        -399.16       288.26          inf        2        inf     start warm-up
#      1         15          63.50         0.01        49.13        2        inf
#      2         20       -8972.09       497.67    121478.10        2   4.08e+06
#      3         25        -419.52        31.09     83986.74        2   2.83e+06
#      4         30      -13638.88     13538.56        61.44        2   9.12e+04
#      5         35       -8552.27     11834.42         0.19        2   5.64e+04
#      6         40          75.91        21.42      9097.37        2   3.06e+05
#      7         45          77.15        16.98         0.02        2       6.81
#      8         50          73.53        14.89         0.00        2       6.18
#      9         55          72.76        12.79         0.03        2       5.65
#         -4.24690507e-02,  5.53384827e-02,  2.66984513e-02,
#         -2.12141458e-02,  4.13226517e-02,  8.35512980e-02,
#         -9.46444079e-02, -1.18538875e-01, -2.51659748e-03,
#         -5.59453330e-03,  3.19265903e-02, -6.11644179e-02,
#         -2.10920408e-02, -9.05067506e-02, -5.77122391e-02,
#          4.98871684e-02,  6.93302043e-02, -4.42368990e-02,
#          6.14571415e-03,  8.83439974e-02, -2.32925311e-02,
#         -3.77838354e-02,  4.22923541e-02, -6.20349603e-03,
#         -1.85332393e-02,  1.65015330e-02,  7.17195965e-03,
#         -1.73804534e-02, -2.21367710e-02]])

# %%
def log_likelihood(theta):
    delta,A = theta
    sol = analytic_sol(t,A,B,delta)
    return np.sum(np.log(1/(sigma* (2*np.pi)**0.5)) - (0.5/sigma**2) * (sol - x_true)**2)

D = 2
LB = np.full((1, D), 0.0)  # Lower bounds
UB = np.full((1, D), 10.0)  # Upper bounds
# LB[0][0] = 0.0
# LB[0][1] = 1.0
# UB[0][0] = 0.99

PUB = np.copy(UB) 
PUB[0][0] = 9.5
PUB[0][1] = 9.5
PLB = np.copy(LB)
PLB[0][0] = 0.5
PLB[0][1] = 0.5

x0 = 3 * np.ones((1, D))
x0[0][0] = delta_min
prior = SplineTrapezoidal(LB, PLB, PUB, UB)

options = {
    "max_fun_evals": 500
}

print("LB:",LB,"PLB:",PLB,"PUB:",PUB,"UB:",UB,'x0:',x0)
# Out:
# LB: [[0. 0.]] PLB: [[0.5 0.5]] PUB: [[9.5 9.5]] UB: [[10. 10.]] x0: [[4.59 3.  ]]

# %%
vbmc2 = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior,options = options) # initialize VMBC object

vp2, results2 = vbmc2.optimize() # do optimization (might take a while)
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 vbmc2 = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior,options = options) # initialize VMBC object
# ----> 3 vp2, results2 = vbmc2.optimize() # do optimization (might take a while)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\vbmc.py:1168, in VBMC.optimize(self)
#    1166     N_slowopts = 1
#    1167 # Run optimization of variational parameters
# -> 1168 self.vp, var_ss, pruned = optimize_vp(
#    1169     self.options,
#    1170     self.optim_state,
#    1171     self.vp,
#    1172     self.gp,
#    1173     N_fastopts,
#    1174     N_slowopts,
#    1175     Knew,
#    1176 )
#    1178 self.optim_state["vp_K"] = self.vp.K
#    1179 # Save current entropy
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:271, in optimize_vp(options, optim_state, vp, gp, fast_opts_N, slow_opts_N, K)
#     268 master_decay = 200
#     269 max_iter = min(10000, options["max_iter_stochastic"])
# --> 271 theta_opt, _, theta_lst, f_val_lst, _ = minimize_adam(
#     272     vb_train_mc_fun,
#     273     theta_opt,
#     274     tol_fun=options["tol_fun_stochastic"],
#     275     max_iter=max_iter,
#     276     master_min=master_min,
#     277     master_max=master_max,
#     278     master_decay=master_decay,
#     279 )
#     281 if options["elcbo_midpoint"]:
#     282     # Recompute ELCBO at best midpoint with full variance
#     283     # and more precision.
#     284     idx_mid = np.argmin(f_val_lst)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\minimize_adam.py:87, in minimize_adam(f, x0, lb, ub, tol_fun, max_iter, master_min, master_max, master_decay, use_early_stopping)
#      84 for i in range(0, max_iter):
#      85     is_minibatch_end = math.remainder(i + 1, batch_size) == 0
# ---> 87     y_tab[i], grad = f(x)
#      89     m = beta_1 * m + (1 - beta_1) * grad
#      90     v = beta_2 * v + (1 - beta_2) * grad**2
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:239, in optimize_vp.<locals>.vb_train_mc_fun(theta_)
#     238 def vb_train_mc_fun(theta_):
# --> 239     res = _neg_elcbo(
#     240         theta_,
#     241         gp,
#     242         vp0,
#     243         elcbo_beta,
#     244         ns_ent_K,
#     245         compute_grad=True,
#     246         compute_var=compute_var,
#     247         theta_bnd=theta_bnd,
#     248     )
#     249     return res[0], res[1]
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:1157, in _neg_elcbo(theta, gp, vp, beta, Ns, compute_grad, compute_var, theta_bnd, _entropy_alpha, separate_K)
#    1148             G, _, varG, _, varG_ss = _gp_log_joint(
#    1149                 vp,
#    1150                 gp,
#    (...)
#    1154                 compute_var,
#    1155             )
#    1156     else:
# -> 1157         G, dG, _, _, _ = _gp_log_joint(
#    1158             vp, gp, grad_flags, avg_flag, jacobian_flag, 0
#    1159         )
#    1160         varG = varG_ss = 0
#    1162 # Entropy term
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:1407, in _gp_log_joint(vp, gp, grad_flags, avg_flag, jacobian_flag, compute_var, separate_K)
#    1405 delta_k = Xt[k, :, :] / tau_k
#    1406 z_k = np.exp(lnnf_k - 0.5 * np.sum(delta_k**2, axis=0))
# -> 1407 I_k = np.dot(z_k, alpha) + m0
#    1409 if quadratic_meanfun:
#    1410     nu_k = -0.5 * np.sum(
#    1411         1
#    1412         / omega**2
#    (...)
#    1419         axis=0,
#    1420     )
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
vp2.plot();

# %%
import scipy.stats as scs
norm1 = scs.norm(loc = -2.0, scale = 1.0)
norm2 = scs.norm(loc = 2.0, scale = 1.0)
x = np.arange(-4,4,0.05)
dual_pdf = norm1.pdf(x) + norm2.pdf(x)

plt.plot(x,np.log(dual_pdf))

# %%
sigma = 0.2
norm1 = scs.multivariate_normal(mean = np.array([2,2]), cov = np.array([[sigma,0],[0,sigma]]))
norm2 = scs.multivariate_normal(mean = np.array([-2,-2]), cov = np.array([[sigma,0],[0,sigma]]))

double_pdf = lambda x: norm1.pdf(x) + norm2.pdf(x)
log_likelihood = lambda x: np.log(double_pdf(x))

x = np.linspace(-8, 8, num=100)
y = np.linspace(-8, 8, num=100)
X, Y = np.meshgrid(x,y)

pdf = np.zeros(X.shape)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        pdf[i,j] = double_pdf([X[i,j], Y[i,j]])

logpdf = np.zeros(X.shape)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        logpdf[i,j] = log_likelihood([X[i,j], Y[i,j]])

fig = plt.figure()	
ax1 = fig.add_subplot(121, projection = '3d')
ax1.plot_surface(X, Y, pdf, cmap = 'viridis')
ax1.set_title("sort of pdf (not normalized)")
plt.xlabel("x1")
plt.ylabel("x2")
ax.axes.zaxis.set_ticks([])


ax2 = fig.add_subplot(122, projection = '3d')
ax2.plot_surface(X, Y, logpdf, cmap = 'viridis')
ax2.set_title("log likelihood")
plt.xlabel("x1")
plt.ylabel("x2")
ax2.axes.zaxis.set_ticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 28
#      26 plt.xlabel("x1")
#      27 plt.ylabel("x2")
# ---> 28 ax.axes.zaxis.set_ticks([])
#      31 ax2 = fig.add_subplot(122, projection = '3d')
#      32 ax2.plot_surface(X, Y, logpdf, cmap = 'viridis')
#
# NameError: name 'ax' is not defined

# %%
D = 2
LB = np.full((1, D), -10.0)  # Lower bounds
UB = np.full((1, D), 10.0)  # Upper bounds


PLB = np.full((1, D), -4.0)  # Plausible Lower bounds
PUB = np.full((1, D), 4.0)  # Plausible Upper bounds

x0 = 2 * np.ones((1, D))

prior = SplineTrapezoidal(LB, PLB, PUB, UB)

options = {
    "max_fun_evals": 500
}

print("LB:",LB,"PLB:",PLB,"PUB:",PUB,"UB:",UB,'x0:',x0)
# Out:
# LB: [[-10. -10.]] PLB: [[-4. -4.]] PUB: [[4. 4.]] UB: [[10. 10.]] x0: [[2. 2.]]

# %%
vbmc3 = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior,options = options) # initialize VMBC object

vp3, results3 = vbmc3.optimize() # do optimization (might take a while)
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10         -19.69         7.79  57291020.77        2        inf     start warm-up
#      1         15          -7.25         3.71         2.54        2        inf
#      2         20          -5.63         0.99         0.31        2       16.1
#      3         25          -4.56         0.02         0.14        2       6.98
#      4         30          -4.55         0.01         0.00        2      0.105
#      5         35          -4.55         0.00         0.00        2     0.0251
#      6         40          -4.59         0.00         0.00        2      0.192     end warm-up
#      7         45          -4.55         0.00         0.00        2      0.167
#      8         50          -4.59         0.00         0.00        2      0.153
#      9         55          -4.59         0.00         0.00        5     0.0162
#     10         60          -4.58         0.00         0.00        8     0.0273     rotoscale, undo rotoscale
#     11         65          -4.59         0.00         0.00       11     0.0279
#     12         70          -4.58         0.00         0.00       11     0.0243
#     13         75          -4.58         0.00         0.00       11     0.0346     stable
#    inf         75          -4.58         0.00         0.00       50     0.0346     finalize
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -4.583 +/-0.001.

# %%
vp3.plot();

# %%
vp3.save("doubly_peaked_vp.pkl")

# %%
from pyvbmc import VariationalPosterior

doubly_peaked_vp = VariationalPosterior.load("doubly_peaked_vp.pkl")

doubly_peaked_vp.plot();

# %%
t = np.arange(0,10,0.05)
A = 2.0
B = 2.0
sigma = 0.05
delta_true = np.pi / 2
print(delta_true)
x_true = analytic_sol(t,A,B,delta_true)

plt.plot(t,x_true)
plt.show()
# Out:
# 1.5707963267948966

# %%
def log_likelihood(theta):
    delta,A,B = theta
    sol = analytic_sol(t,A,B,delta)
    return np.sum(np.log(1/(sigma* (2*np.pi)**0.5)) - (0.5/sigma**2) * (sol - x_true)**2)

D = 3
LB = np.full((1, D), 0.0)  # Lower bounds
UB = np.full((1, D), 10.0)  # Upper bounds

PLB = np.full((1, D), 0.5)
PUB = np.full((1, D), 9.5)

x0 = 3 * np.ones((1, D))
x0[0][0] = delta_min
prior = SplineTrapezoidal(LB, PLB, PUB, UB)

options = {
    "max_fun_evals": 500
}

print("LB:",LB,"PLB:",PLB,"PUB:",PUB,"UB:",UB,'x0:',x0)
# Out:
# LB: [[0. 0. 0.]] PLB: [[0.5 0.5 0.5]] PUB: [[9.5 9.5 9.5]] UB: [[10. 10. 10.]] x0: [[4.64 3.   3.  ]]

# %%
vbmc4 = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior,options = options) # initialize VMBC object

vp4, results4 = vbmc4.optimize() # do optimization (might take a while)
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10      -74546.81     22348.56          inf        2        inf     start warm-up
#      1         15      -69203.57     39317.61 431348354.72        2        inf
#      2         20      -83554.72      4987.96    211185.49        2   4.13e+06
#      3         25      -69431.74     15660.55 12358545002.29        2   2.38e+11
# c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\evolution_strategy.py:3829: RuntimeWarning: invalid value encountered in scalar subtract
#   current_fitness_range < opts['tolfunrel'] * (es.fit.median0 - es.fit.median_min),
# c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\evolution_strategy.py:3829: RuntimeWarning: invalid value encountered in scalar multiply
#   current_fitness_range < opts['tolfunrel'] * (es.fit.median0 - es.fit.median_min),
#      4         30      -79499.07      1139.82    177346.10        2   3.45e+06
#      5         35      -79843.79       944.70     13958.58        2   2.73e+05
#      6         40      -62414.33     16591.94 7032736349.94        2   1.35e+11
#      7         45      -65628.76     15959.82     13033.18        2   3.15e+05
#      8         50      -74972.59      4056.26     83390.86        2   1.65e+06
#     54        280      -65588.62      4132.30   6805738.16       11   1.31e+08
#     55        285      -65597.55      2162.28        86.59       11    8.9e+03
#     56        290      -65614.30      1723.02        13.85       11   6.07e+03
#     57        295      -58887.17      2892.81       845.63       11   4.83e+04
#     58        300      -65701.97      1537.71      3148.13       12   8.84e+04
#     59        305      -65670.58       411.74         8.11       12   1.63e+03
#     60        310      -64110.54      1698.10        17.12       13   1.12e+04
#     61        315      -58870.11      3306.27      4228.84       13    1.1e+05
# c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\evolution_strategy.py:3824: RuntimeWarning: invalid value encountered in scalar subtract
#   historic_fitness_range = max(es.fit.hist) - min(es.fit.hist)
#     62        320      -58881.62      4018.65       131.68       13    1.6e+04
#     63        325      -65758.98      2644.38      6428.03       13   1.55e+05
#     64        330      -58936.88      3413.80      8318.97       13   1.94e+05
#     65        335      -58879.03      3641.93        26.54       13   1.28e+04
#     66        340      -65905.35      2070.59     27961.31       13   5.68e+05
#     67        345      -65849.79      2236.35        26.12       13   8.14e+03
#     68        350      -65836.60      2695.80         8.10       13   9.19e+03
#     69        355      -65797.46      2733.51        22.78       13   9.68e+03
#     70        360      -65947.76      3141.68        17.49       13   1.13e+04
#     71        365      -65920.70      3223.64         0.85       13   1.09e+04
#     72        370      -58885.91      4407.14   3615090.88       13   6.96e+07
#     73        375      -65967.20      3568.19   7860060.01       14   1.51e+08
#     74        380      -65955.17      2516.81        27.27       14   8.95e+03
#     75        385      -58868.68      3200.11      6929.93       14   1.68e+05
#     76        390      -58918.59      1568.87      5984.00       15   1.21e+05
#     77        395      -58995.50       808.18        75.41       16    4.4e+03
#     78        400      -58877.54       398.76      1690.80       17   3.43e+04
#     79        405      -58875.66       294.28         3.90       18   1.06e+03
#     80        410      -58877.72       258.00         0.36       19        874
#     81        415      -58871.54       239.61         0.58       20        830
#     82        420      -58872.91       246.47         0.50       21        836
#     83        425      -58861.58       248.08         0.22       21        869
#     84        430      -58864.77       326.83        50.17       21   2.07e+03
#     85        435      -58864.88       265.76         6.50       21   1.01e+03
#     86        440      -58837.59       136.50        36.38       21   1.25e+03
#     87        445      -58854.45       177.38         5.08       22        745
#     88        450      -58858.38       129.48         1.00       22        464
#     89        455      -58850.34       145.57         1.18       23        535
#     90        460      -58860.70       171.26         1.28       23        630
#     91        465      -58868.06       143.11         1.04       23        522
#     92        470      -58853.53       186.24         4.09       23        748
#     93        475      -58841.15       210.94         0.50       23        754
#     94        480      -58858.33       172.23         0.34       23        638
#     95        485      -59242.45       141.01       182.66       23   5.27e+03
#     96        490      -58867.14      1094.59     30867.69       23   5.99e+05
#     97        495      -58873.34       923.42         2.83       23   3.15e+03
#     98        500      -58922.29       861.45         3.07       23   3.09e+03
#    inf        500      -58864.84       291.78     14102.54       50        464     finalize
# Inference terminated: reached maximum number of function evaluations options.max_fun_evals.
# Estimated ELBO: -58864.842 +/-291.777.
# Caution: Returned variational solution may have not converged.

# %%
vp4.plot();

# %%
vp4.moments()
# Out:
# array([[4.44759698, 1.70286852, 1.67912972]])

# %%
print(delta,A,B)
# Out:
# 9.86 2.0 2.0

# %%
print(np.pi/2, 2 * np.pi * np.pi / 2)
# Out:
# 1.5707963267948966 9.869604401089358

# %%
vp4.save("3D_vp.pkl")

# %%
sigma = 0.2
D = 3
norm1 = scs.multivariate_normal(mean = np.array([2.,2.,2.]), cov = sigma * np.identity(D))
norm2 = scs.multivariate_normal(mean = np.array([-2.,-2.,-2.]), cov = sigma * np.identity(D))

double_pdf = lambda x: norm1.pdf(x) + norm2.pdf(x)
log_likelihood = lambda x: np.log(double_pdf(x))

D = 3
LB = np.full((1, D), -15.0)  # Lower bounds
UB = np.full((1, D), 15.0)  # Upper bounds


PLB = np.full((1, D), -3.0)  # Plausible Lower bounds
PUB = np.full((1, D), 3.0)  # Plausible Upper bounds

x0 = np.array([[0.0,0.0,0.0]])

prior = SplineTrapezoidal(LB, PLB, PUB, UB)

# options = {
#     "max_fun_evals": 500
# }
from pyvbmc.acquisition_functions import AcqFcnLog, AcqFcnVIQR, AcqFcnNoisy

options = {
    "search_acq_fcn": [AcqFcnVIQR()]

}

print("LB:",LB,"PLB:",PLB,"PUB:",PUB,"UB:",UB,'x0:',x0)
# Out:
# LB: [[-15. -15. -15.]] PLB: [[-3. -3. -3.]] PUB: [[3. 3. 3.]] UB: [[15. 15. 15.]] x0: [[0. 0. 0.]]

# %%
log_likelihood([2.,2.,2.])
# Out:
# -0.34265873096286775

# %%
vbmc5 = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior,options = options) # initialize VMBC object

vp5, results5 = vbmc5.optimize() # do optimization (might take a while)
print(vp5.moments())
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10         -35.34         6.80     74538.94        2        inf     start warm-up
#      1         15         -13.56         5.72        13.07        2        inf
#      2         20          -9.03         0.22         1.24        2       39.8
#      3         25          -8.63         0.09         0.48        2       10.9
#      4         30          -8.67         0.02         0.03        2      0.844
#      5         35          -8.69         0.01         0.00        2      0.173
#      6         40          -8.69         0.00         0.00        2     0.0888
#      7         45          -8.67         0.00         0.00        2      0.109     end warm-up
#      8         50          -8.67         0.00         0.00        2     0.0477
#      9         55          -8.67         0.00         0.00        2     0.0225
#     10         60          -8.69         0.00         0.00        5       0.13
#     11         65          -8.67         0.00         0.00        5      0.116     rotoscale, undo rotoscale
#     12         70          -8.67         0.00         0.00        5     0.0291
#     13         75          -8.67         0.00         0.00        5     0.0094     stable
#    inf         75          -8.67         0.00         0.00       50     0.0094     finalize
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -8.672 +/-0.001.
# [[1.99984851 2.0017516  2.00053254]]

# %%
vp5.plot();

# %%
# Out:
# array([[1.99954665, 1.99994812, 2.00040237]])
