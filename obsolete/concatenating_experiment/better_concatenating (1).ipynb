# %% [markdown]
# (From Alia) Actually making all the vps for the various a and b. This was for the big picture thing on our poster and the heatmaps. This is the second version of it, where concatenation is included.

# %%
import pandas as pd  # Data handling
from scipy.integrate import odeint # numerical integration
import numpy as np
from pyvbmc import VBMC # VMBC object
from pyvbmc import VariationalPosterior
from pyvbmc.priors import SplineTrapezoidal
from scipy.optimize import minimize
import scipy.stats as scs
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from pyvbmc import VariationalPosterior

def derivs(t,curr_vals,a,b):
    x,xd = curr_vals
    xdd = -x - np.sign(x) * a * np.abs(x)**b
    return  xd,xdd

# time array for solution
tmax = 10
dt = 0.05
t = np.arange(0,tmax,dt)

# Range of values that parameters can take on
a_min = 0.0
a_max = 0.5
b_min = 1.0
b_max = 5.0

# Number of parameters (dimension)
D = 2

# Bounds for VBMC object (LB and UB expanded a bit beyond what the actual true values could be)
LB = np.full((1, D), a_min)
LB[0][0] = a_min
LB[0][1] = b_min - 1
UB = np.full((1, D), a_max)
UB[0][0] = a_max + 0.1
UB[0][1] = b_max + 1
PLB = np.copy(LB)
PLB[0][0] = a_min + 0.01
PLB[0][1] = b_min
PUB = np.copy(UB)
PUB[0][0] = a_max 
PUB[0][1] = b_max

# pick a random starting point and do initial minimizatio on it
np.random.seed(4) # leave this
x0_rand = np.random.uniform(PLB, PUB)

#set up prior
prior = SplineTrapezoidal(LB, PLB, PUB, UB)
options = {
    "display": "off"
}

print("LB:",LB,"PLB:",PLB,"PUB:",PUB,"UB:",UB,'x0_rand:',x0_rand)

def log_likelihood(theta):
    a,b = theta
    sols = []
    for initial_condition in initial_conditions:
        sol = solve_ivp(derivs,(0,tmax),initial_condition,t_eval = t, args = (a,b), method = "LSODA").y
        sols.append(sol[0])
    big_sol = np.concatenate(sols)
    sliced_sol = big_sol[0::4]
    LL =  np.sum(-(0.5/sigma**2) * (y_true - sliced_sol)**2) #+ np.log(1/(sigma* (2*np.pi)**0.5))
    return LL

initial_conditions = [[0.0, 3.5],[2.0, 0.0],[-0.5, -0.5],[3.14, -0.3]]

sigma = 0.1
noise_sigma = 0.05

a = 0.3
b = 2.0
sols = []

N = 7
a_vals = np.linspace(0.1,0.5,N)
b_vals = np.linspace(1.1,3.5,N)
print(a_vals)
print(b_vals)
# Out:
# LB: [[0. 0.]] PLB: [[0.01 1.  ]] PUB: [[0.5 5. ]] UB: [[0.6 6. ]] x0_rand: [[0.48384462 3.188929  ]]
# [0.1        0.16666667 0.23333333 0.3        0.36666667 0.43333333
#  0.5       ]
# [1.1 1.5 1.9 2.3 2.7 3.1 3.5]

# %%
seeds = np.array([0,1]) # CHANGE THIS
count = 0
for seed in seeds:
    
    for i,a in enumerate(a_vals):

        for j,b in enumerate(b_vals):
            sols = []
            for initial_condition in initial_conditions:
                sol = solve_ivp(derivs,(0,tmax),initial_condition,t_eval = t, args = (a,b),method = "LSODA").y
                sols.append(sol[0])
            big_sol = np.concatenate(sols)
            sliced = big_sol[0::4]
            np.random.seed(seed)
            noisy_sliced_sol = sliced + noise_sigma * np.random.randn(len(sliced))
            y_true = noisy_sliced_sol
            np.random.seed(seed)
            count += 1
            np.random.seed(seed)
            x0 = np.random.uniform(PLB, PUB)
            np.random.seed(seed)
            vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior, options = options)
            np.random.seed(seed)
            vp, results = vbmc.optimize()
            vp.save("vp" + str(i) + "_" +  str(j) + "_" + str(seed) + ".hdf5", overwrite=True)
print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      22             vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = prior, options = options)
#      23             np.random.seed(seed)
# ---> 24             vp, results = vbmc.optimize()
#      25             vp.save("vp" + str(i) + "_" +  str(j) + "_" + str(seed) + ".hdf5", overwrite=True)
#      26 print(count)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\vbmc.py:1094, in VBMC.optimize(self)
#    1087     else:
#    1088         self.optim_state["hyp_dict"] = self.hyp_dict
#    1089         (
#    1090             self.function_logger,
#    1091             self.optim_state,
#    1092             self.vp,
#    1093             self.gp,
# -> 1094         ) = active_sample(
#    1095             gp_search,
#    1096             new_funevals,
#    1097             self.optim_state,
#    1098             self.function_logger,
#    1099             self.iteration_history,
#    1100             self.vp,
#    1101             self.options,
#    1102         )
#    1103         self.hyp_dict = self.optim_state["hyp_dict"]
#    1105 # Number of training inputs
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\active_sample.py:398, in active_sample(gp, sample_count, optim_state, function_logger, iteration_history, vp, options)
#     389     insigma = np.sqrt(np.diag(Sigma))
#     390     cma_options = {
#     391         "verbose": -9,
#     392         "tolfun": tol_fun,
#    (...)
#     395         "seed": np.nan,
#     396     }
# --> 398     res = cma.fmin(
#     399         acq_fun,
#     400         x0,
#     401         np.max(insigma),
#     402         options=cma_options,
#     403         noise_handler=cma.NoiseHandler(np.size(x0)),
#     404     )
#     406     xsearch_optim, f_val_optim = res[:2]
#     407 elif options["search_optimizer"] == "Nelder-Mead":
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\evolution_strategy.py:4842, in fmin(objective_function, x0, sigma0, options, args, gradf, restarts, restart_from_best, incpopsize, eval_initial_x, parallel_objective, noise_handler, noise_change_sigma_exponent, noise_kappa_exponent, bipop, callback)
#    4840 es.tell(X, fit)  # prepare for next iteration
#    4841 if noise_handling:  # it would be better to also use these f-evaluations in tell
# -> 4842     es.sigma *= noisehandler(X, fit, objective_function, es.ask,
#    4843                              args=args)**fmin_opts['noise_change_sigma_exponent']
#    4845     es.countevals += noisehandler.evaluations_just_done  # TODO: this is a hack, not important though
#    4846     # es.more_to_write.append(noisehandler.evaluations_just_done)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\optimization_tools.py:707, in NoiseHandler.__call__(self, X, fit, func, ask, args)
#     705 if not self.maxevals or self.lam_reeval == 0:
#     706     return 1.0
# --> 707 res = self.reeval(X, fit, func, ask, args)
#     708 if not len(res):
#     709     return 1.0
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\optimization_tools.py:746, in NoiseHandler.reeval(self, X, fit, func, ask, args)
#     744         self.fitre[i] = fagg(func(ask(evals, X_i, self.epsilon), *args))
#     745     else:
# --> 746         self.fitre[i] = fagg([func(ask(1, X_i, self.epsilon)[0], *args)
#     747                                 for _k in range(evals)])
#     748 else:
#     749     self.fitre[i] = fagg([func(X_i, *args) for _k in range(evals)])
#
# File <__array_function__ internals>:200, in median(*args, **kwargs)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\numpy\lib\function_base.py:3856, in median(a, axis, out, overwrite_input, keepdims)
#    3774 @array_function_dispatch(_median_dispatcher)
#    3775 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3776     """
#    3777     Compute the median along the specified axis.
#    3778
#    (...)
#    3854
#    3855     """
# -> 3856     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#    3857                     overwrite_input=overwrite_input)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\numpy\lib\function_base.py:3752, in _ureduce(a, func, keepdims, **kwargs)
#    3749             index_out = (0, ) * nd
#    3750             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3752 r = func(a, **kwargs)
#    3754 if out is not None:
#    3755     return out
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\numpy\lib\function_base.py:3887, in _median(a, axis, out, overwrite_input)
#    3885         part = a
#    3886 else:
# -> 3887     part = partition(a, kth, axis=axis)
#    3889 if part.shape == ():
#    3890     # make 0-D arrays work
#    3891     return part.item()
#
# File <__array_function__ internals>:200, in partition(*args, **kwargs)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\numpy\core\fromnumeric.py:784, in partition(a, kth, axis, kind, order)
#     782 else:
#     783     a = asanyarray(a).copy(order="K")
# --> 784 a.partition(kth, axis=axis, kind=kind, order=order)
#     785 return a
#
# KeyboardInterrupt:
