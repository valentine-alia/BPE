# %% [markdown]
# ## SOLUTION: ODE challenge 1

# %%
import pandas as pd  # Data handling
import matplotlib.pyplot as plt # visualization
from scipy.integrate import odeint # numerical integration
import numpy as np
from pyvbmc import VBMC # VMBC object
import scipy.stats as scs # scipy stats to get distributions from
from pyvbmc.priors import UniformBox, Trapezoidal, SplineTrapezoidal, SmoothBox # nice priors from PyVBMC

# %% [markdown]
# First read in data:

# %%
data = pd.read_csv("anna_ode_challenge_1_data.csv")

t_data = data["timestamp"]
x_data = data["value"]

# %%
plt.plot(t_data,x_data)
plt.show()

# %% [markdown]
# ### Solution method: Parameter sweep using scipy's ODEint
#
# To solve this problem, we can sweep over different values of $\varepsilon$, using our model to produce results for each one. Then we'll compare these results to the true data and see which one reproduces the original data the closest.

# %%
def diffyqs(X, t, a): # fn to pass to solver (essentially identical to the Julia solver but indexed different)
    y = X
    dydt = -a*y
    return dydt

# %%
# initial conditions (could get these from data)
x0_1 = [x_data[0]]

# use time data as time array for solver
t = t_data

# %% [markdown]
# ### "by hand" solution

# %%
def log_likelihood(theta):
    a = theta
    sol = odeint(diffyqs, x0_1, t, args=(a,))
    return -np.sum((sol.T[0] - x_data)**2) ## FROM GAUSSIAN

sols = []
for i in np.arange(0,1,0.01):
    sols.append(log_likelihood(i))
print("best choice for a:",np.arange(0,1,0.01)[np.argmax(np.array(sols))])
plt.plot(sols)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 sols = []
#       7 for i in np.arange(0,1,0.01):
# ----> 8     sols.append(log_likelihood(i))
#       9 print("best choice for a:",np.arange(0,1,0.01)[np.argmax(np.array(sols))])
#      10 plt.plot(sols)
#
# Cell In[6], line 3, in log_likelihood(theta)
#       1 def log_likelihood(theta):
#       2     a = theta
# ----> 3     sol = odeint(diffyqs, x0_1, t, args=(a,))
#       4     return -np.sum((sol.T[0] - x_data)**2)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\scipy\integrate\_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# Cell In[4], line 1, in diffyqs(X, t, a)
# ----> 1 def diffyqs(X, t, a): # fn to pass to solver (essentially identical to the Julia solver but indexed different)
#       2     y = X
#       3     dydt = -a*y
#
# KeyboardInterrupt:

# %% [markdown]
# ## Solution with PyVBMC

# %%
D = 1  

LB = np.full((1, D), 0)  # Lower bounds 
UB = np.full((1, D), 10)  # Upper bounds 

PLB = np.copy(LB)
PUB = np.copy(UB) 
PUB[0][0] = 1
PLB[0][0] = 0.1

x0 = 3 * np.ones((1, D))

# %%
vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = UniformBox(LB, UB)) # initialize VMBC object

vp, results = vbmc.optimize() # do optimization (might take a while)
# Out:
# Casting lower bounds to floating point.
# Casting upper bounds to floating point.
# Casting plausible lower bounds to floating point.
# Casting plausible upper bounds to floating point.
# vbmc:TooCloseBounds: For each variable, hard and plausible bounds should not be too close. Moving plausible bounds.
# vbmc:InitialPointsOutsidePB. The starting points X0 are not inside the provided plausible bounds PLB and PUB. Expanding the plausible bounds...
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10         114.19        51.50 253028167525316001792.00        2        inf     start warm-up
#      1         15          -6.90         0.00        10.62        2        inf
#      2         20          -6.89         0.00         0.01        2      0.408
#      3         25          -6.89         0.00         0.01        2      0.468
#      4         30          -6.88         0.00         0.00        2     0.0381
#      5         35          -6.88         0.00         0.00        2     0.0257
#      6         40          -6.90         0.00         0.00        2     0.0885     end warm-up
#      7         45          -6.89         0.00         0.01        2      0.401
#      8         50          -6.89         0.00         0.00        2      0.116
#      9         55          -6.91         0.00         0.02        5       0.59
#     10         60          -7.19         0.00         0.24        5       8.86
#     11         65          -6.92         0.00         0.19        5       7.22
#     12         70          -6.92         0.00         0.04        5       1.22
#     13         75          -7.00         0.00         0.02        5      0.902
#     14         80          -6.99         0.00         0.03        5       1.18
#     15         85          -6.92         0.00         0.11        5        3.9
#     16         90          -6.90         0.00         0.02        6      0.698
#     17         95          -7.01         0.00         0.04        9       1.82
#     18        100          -7.04         0.00         0.11        9       3.85
#     19        105          -6.95         0.00         0.08        9       3.03
#     20        110          -6.94         0.00         0.01        9      0.452
#     21        115          -6.94         0.00         0.05       12       1.54
#     22        120          -6.92         0.00         0.04       12       1.35
#     23        125          -6.90         0.00         0.02       13      0.854
#     24        130          -6.91         0.00         0.00       16     0.0758
#     25        135          -6.94         0.00         0.01       16      0.567
#     26        140          -6.91         0.00         0.01       16      0.334
#     27        145          -6.91         0.00         0.00       16      0.146
#     28        150          -7.15         0.00         0.10       16       3.99
#    inf        150          -6.93         0.00         0.02       50      0.854     finalize
# Inference terminated: reached maximum number of function evaluations options.max_fun_evals.
# Estimated ELBO: -6.931 +/-0.000.
# Caution: Returned variational solution may have not converged.

# %%
vp.plot();

# %%
n_samples = int(5e5)
Xs, _ = vp.sample(n_samples)

post_mean = np.mean(Xs, axis=0)  # Posterior mean
print("The approximate value of a:", post_mean)


a =  post_mean[0]

sol = odeint(diffyqs, x0_1, t, args=(a,))

plt.figure(figsize=(8,5))
plt.title("1 parameter Solution from Uniform Box Prior")
plt.plot(t,sol.T[0], label = "predicted solution from BPE params")
plt.plot(t,x_data, label = "true data")
plt.grid()
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()
# Out:
# The approximate value of a: [0.44026417]

# %%
def diffyqs(X, t, a, b): # fn to pass to solver (essentially identical to the Julia solver but indexed different)
    y = X
    dydt = -(a + b)*y
    return dydt

# initial conditions (could get these from data)
x0_1 = [x_data[0]]

# use time data as time array for solver
t = t_data

def log_likelihood(theta):
    a,b = theta
    sol = odeint(diffyqs, x0_1, t, args=(a,b))
    return -np.sum((sol.T[0] - x_data)**2) ## FROM GAUSSIAN

D = 2

LB = np.full((1, D), 0)  # Lower bounds 
UB = np.full((1, D), 1000)  # Upper bounds 

PLB = np.copy(LB)
PUB = np.copy(UB) 
PUB[0][0] = 10
PLB[0][0] = 0.1

PUB[0][1] = 10
PLB[0][1] = 0.1

x0 = 3 * np.ones((1, D))

# %%
vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = UniformBox(LB, UB)) # initialize VMBC object

vp, results = vbmc.optimize(); # do optimization (might take a while)
# Out:
# Casting lower bounds to floating point.
# Casting upper bounds to floating point.
# Casting plausible lower bounds to floating point.
# Casting plausible upper bounds to floating point.
# vbmc:TooCloseBounds: For each variable, hard and plausible bounds should not be too close. Moving plausible bounds.
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10       -6835.97       939.58  98011030.34        2        inf     start warm-up
#      1         15         -22.06         0.30     15603.41        2        inf
#      2         20         -22.29         0.59        13.57        2        323
#      3         25         -22.29         0.00         0.07        2       1.67
#      4         30         -22.31         0.00         0.00        2      0.175
#      5         35         -22.29         0.00         0.00        2      0.131
#      6         40         -22.31         0.00         0.00        2      0.175     end warm-up
#      7         45         -22.29         0.00         0.01        2      0.251
#      8         50         -22.31         0.00         0.00        2     0.0675
#      9         55         -21.73         0.00         0.16        5       5.59
#     10         60         -21.47         0.00         0.18        6       5.03
#     11         65         -21.44         0.00         0.11        7       2.66
#     12         65         -20.85         0.03         0.25        8       7.97     rotoscale
#     13         70         -20.86         0.00         0.00        9      0.122
#     14         75         -20.79         0.00         0.00       12      0.319
#     15         80         -20.74         0.00         0.01       13      0.407
#     16         85         -20.70         0.00         0.00       13      0.155
#     17         90         -20.67         0.00         0.00       13       0.14
#     18         95         -20.65         0.00         0.00       13      0.119     rotoscale, undo rotoscale
#     19        100         -20.64         0.00         0.00       14     0.0716
#     20        105         -20.61         0.00         0.00       14      0.105
#     21        110         -20.59         0.00         0.00       13     0.0755
#     22        115         -20.58         0.00         0.00       13     0.0649     stable
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = UniformBox(LB, UB)) # initialize VMBC object
# ----> 3 vp, results = vbmc.optimize(); # do optimization (might take a while)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\vbmc.py:1494, in VBMC.optimize(self)
#    1490 self.vp, elbo, elbo_sd, idx_best = self.determine_best_vp()
#    1492 if self.options.get("do_final_boost"):
#    1493     # Last variational optimization with large number of components
# -> 1494     self.vp, elbo, elbo_sd, changed_flag = self.final_boost(
#    1495         self.vp, self.iteration_history["gp"][idx_best]
#    1496     )
#    1497 else:
#    1498     changed_flag = False
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\vbmc.py:2020, in VBMC.final_boost(self, vp, gp)
#    2017 self.optim_state["entropy_alpha"] = 0
#    2019 stable_flag = np.copy(vp.stats["stable"])
# -> 2020 vp, __, __ = optimize_vp(
#    2021     options,
#    2022     self.optim_state,
#    2023     vp,
#    2024     gp,
#    2025     n_fast_opts,
#    2026     n_slow_opts,
#    2027     K_new,
#    2028 )
#    2029 vp.stats["stable"] = stable_flag
#    2030 changed_flag = True
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:271, in optimize_vp(options, optim_state, vp, gp, fast_opts_N, slow_opts_N, K)
#     268 master_decay = 200
#     269 max_iter = min(10000, options["max_iter_stochastic"])
# --> 271 theta_opt, _, theta_lst, f_val_lst, _ = minimize_adam(
#     272     vb_train_mc_fun,
#     273     theta_opt,
#     274     tol_fun=options["tol_fun_stochastic"],
#     275     max_iter=max_iter,
#     276     master_min=master_min,
#     277     master_max=master_max,
#     278     master_decay=master_decay,
#     279 )
#     281 if options["elcbo_midpoint"]:
#     282     # Recompute ELCBO at best midpoint with full variance
#     283     # and more precision.
#     284     idx_mid = np.argmin(f_val_lst)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\minimize_adam.py:87, in minimize_adam(f, x0, lb, ub, tol_fun, max_iter, master_min, master_max, master_decay, use_early_stopping)
#      84 for i in range(0, max_iter):
#      85     is_minibatch_end = math.remainder(i + 1, batch_size) == 0
# ---> 87     y_tab[i], grad = f(x)
#      89     m = beta_1 * m + (1 - beta_1) * grad
#      90     v = beta_2 * v + (1 - beta_2) * grad**2
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:239, in optimize_vp.<locals>.vb_train_mc_fun(theta_)
#     238 def vb_train_mc_fun(theta_):
# --> 239     res = _neg_elcbo(
#     240         theta_,
#     241         gp,
#     242         vp0,
#     243         elcbo_beta,
#     244         ns_ent_K,
#     245         compute_grad=True,
#     246         compute_var=compute_var,
#     247         theta_bnd=theta_bnd,
#     248     )
#     249     return res[0], res[1]
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\variational_optimization.py:1165, in _neg_elcbo(theta, gp, vp, beta, Ns, compute_grad, compute_var, theta_bnd, _entropy_alpha, separate_K)
#    1162 # Entropy term
#    1163 if Ns > 0:
#    1164     # Monte carlo approximation
# -> 1165     H, dH = entmc_vbmc(vp, Ns, grad_flags, jacobian_flag)
#    1166 else:
#    1167     # Deterministic approximation via lower bound on the entropy
#    1168     H, dH = entlb_vbmc(vp, grad_flags, jacobian_flag)
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\entropy\entmc_vbmc.py:86, in entmc_vbmc(vp, Ns, grad_flags, jacobian_flag)
#      83 if any(grad_flags):
#      84     # Full mixture (for sample from the j-th component)
#      85     norm_j1 = ((Xs[..., None] - mu) / sigmalambd) ** 2  # [Ns, D, K]
# ---> 86     norm_j1 = norm_j1.sum(1)  # [Ns, K]
#      87     norm_j1 = np.exp(-0.5 * norm_j1)
#      88     norm_j1 = nconst / (sigma**D) * norm_j1  # [Ns, K]
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\numpy\core\_methods.py:47, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
#      45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
#      49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#
# KeyboardInterrupt:

# %%
vp.plot();

# %%
n_samples = int(5e5)
Xs, _ = vp.sample(n_samples)

post_mean = np.mean(Xs, axis=0)  # Posterior mean
print("The approximate value of a:", post_mean)


a =  post_mean[0]
b =  post_mean[1]

sol = odeint(diffyqs, x0_1, t, args=(a,b))

plt.figure(figsize=(8,5))
plt.title("2 redundant parameter Solution from Uniform Box Prior")
plt.plot(t,sol.T[0], label = "predicted solution from BPE params")
plt.plot(t,x_data, label = "true data")
plt.grid()
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()
# Out:
# The approximate value of a: [0.32510616 0.11527652]

# %%
def CI_1D(pdf,true_value,step):
    a,b = pdf_mode - step, pdf_mode + step
    I = 0
    def check_if_in_CI(true_value,a,b):
        if a <= true_value and true_value <= b:
            return False
        else:
            return True
    while check_if_in_CI(true_value,a,b):
        I = integrate(pdf,a,b)
        a -= step
        b += step
    return I

# %%
vp.pdf(np.array([[0]]))
simple_pdf = lambda x: vp.pdf(np.array([[x]]))
I0 = integrate.quad(vp.pdf,0,3)
I1 = integrate.quad(simple_pdf,0,1)

print(I0[0],I1[0])
# Out:
# 1.000000000000008 1.000000000000008

# %%
x_range = np.arange(-5,5,0.01)
y = np.array([simple_pdf(x) for x in x_range])
x_range[np.argmax(y)]
# Out:
# 0.43999999999988404

# %%
norm = scs.norm(loc = 0, scale = 0.5)

plt.plot(np.arange(-3,3,0.1),norm.pdf(np.arange(-3,3,0.1)))

# %%
import scipy.stats as scs
import scipy.integrate as integrate
import numpy as np
import matplotlib.pyplot as plt

sigma = 0.5
norm = scs.norm(loc = 0, scale = sigma)
plt.plot(np.arange(-3,3,0.1),norm.pdf(np.arange(-3,3,0.1)))
plt.show()

def CI_1D(pdf,true_value,step = 0.05,x_lb = -10,x_ub = 10):
    x_range = np.arange(x_lb,x_ub,step)
    y = np.array([pdf(x) for x in x_range])
    pdf_mode = x_range[np.argmax(y)]
    a,b = pdf_mode - step, pdf_mode + step
    I = 0
    def check_if_in_CI(true_value,a,b):
        if a <= true_value and true_value <= b:
            return False
        else:
            return True
    while check_if_in_CI(true_value,a,b):
        
        a -= step
        b += step
    I = integrate.quad(pdf, a, b)[0]
    return I

print("1 std CI:",CI_1D(norm.pdf,1,0.01))

# TODO: make fast version that uses knowledge of truth to not have to iterate

# example of how you could use it with PyVBMC
#simple_pdf = lambda x: vp.pdf(np.array([[x]]))
#CI_1D(simple_pdf,0.44,0.1)
# Out:
# 1 std CI: 0.9566166124647066

# %%
# example of how you could use it with PyVBMC
#simple_pdf = lambda x: vp.pdf(np.array([[x]]))
CI_1D(vp.pdf,0.44,0.1)
# Out:
# 0

# %%
sigma = 0.5
cov = np.array([[sigma,0],[0,sigma]])
norm = scs.multivariate_normal(cov = cov)


def CI_2D(vp,pdf,true_value,step = 0.05,x_lb = -10,x_ub = 10,n_samples = int(5e5)):
    # do sampling, take mode of samples
    Xs, _ = vp.sample(n_samples) # sample vp
    pdf_mode = scs.mode(Xs)
    a,b = pdf_mode - step, pdf_mode + step
    I = 0
    def check_if_in_CI(true_value,a,b):
        if a <= true_value[0] and true_value[0] <= b \
            and a <= true_value[1] and true_value[1] <= b:
            return False
        else:
            return True
    while check_if_in_CI(true_value,a,b):
        I = integrate.dblquad(pdf, a, b, a, b)[0]
        a -= step
        b += step
    return I

print("1 std CI:$",CI_2D(vp,norm.pdf,[0.5,0.5],0.01))
# Out:
# C:\Users\walki\AppData\Local\Temp\ipykernel_1248\409915409.py:9: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   pdf_mode = scs.mode(Xs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 24
#      21         b += step
#      22     return I
# ---> 24 print("1 std CI:$",CI_2D(vp,norm.pdf,[0.5,0.5],0.01))
#
# Cell In[79], line 10, in CI_2D(vp, pdf, true_value, step, x_lb, x_ub, n_samples)
#       8 Xs, _ = vp.sample(n_samples) # sample vp
#       9 pdf_mode = scs.mode(Xs)
# ---> 10 a,b = pdf_mode - step, pdf_mode + step
#      11 I = 0
#      12 def check_if_in_CI(true_value,a,b):
#
# TypeError: unsupported operand type(s) for -: 'ModeResult' and 'float'

# %%
norm.pdf([0,3])
# Out:
# 3.928256069279485e-05
