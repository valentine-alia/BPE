# %%
import pandas as pd  # Data handling
import matplotlib.pyplot as plt # visualization
from scipy.integrate import odeint # numerical integration
import numpy as np
from pyvbmc import VBMC # VMBC object
import scipy.stats as scs # scipy stats to get distributions from
from pyvbmc.priors import UniformBox, Trapezoidal, SplineTrapezoidal, SmoothBox # nice priors from PyVBMC

# %% [markdown]
# This code shamelessly stolen from https://matplotlib.org/3.2.2/gallery/animation/double_pendulum_sgskip.html

# %%
def diffyqs(state, t,G, L1, L2, M1, M2):

    dydx = np.zeros_like(state)
    dydx[0] = state[1]

    delta = state[2] - state[0]
    den1 = (M1+M2) * L1 - M2 * L1 * np.cos(delta) * np.cos(delta)
    dydx[1] = ((M2 * L1 * state[1] * state[1] * np.sin(delta) * np.cos(delta)
                + M2 * G * np.sin(state[2]) * np.cos(delta)
                + M2 * L2 * state[3] * state[3] * np.sin(delta)
                - (M1+M2) * G * np.sin(state[0]))
               / den1)

    dydx[2] = state[3]

    den2 = (L2/L1) * den1
    dydx[3] = ((- M2 * L2 * state[3] * state[3] * np.sin(delta) * np.cos(delta)
                + (M1+M2) * G * np.sin(state[0]) * np.cos(delta)
                - (M1+M2) * L1 * state[1] * state[1] * np.sin(delta)
                - (M1+M2) * G * np.sin(state[2]))
               / den2)

    return dydx


# initial condition
th1 = 120.0
w1 = 0.0
th2 = -10.0
w2 = 0.0
initial_condition = np.radians([th1, w1, th2, w2])

# parameters
G = 9.8  # acceleration due to gravity, in m/s^2
L1 = 1.0  # length of pendulum 1 in m
L2 = 1.0  # length of pendulum 2 in m
M1 = 1.0  # mass of pendulum 1 in kg
M2 = 1.0  # mass of pendulum 2 in kg

# time setup
dt = 0.05
t = np.arange(0, 10, dt)


#integrate
y = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2))

# %%
x1 = L1*np.sin(y[:, 0])
y1 = -L1*np.cos(y[:, 0])

x2 = L2*np.sin(y[:, 2]) + x1
y2 = -L2*np.cos(y[:, 2]) + y1

# %%
plt.plot(y[:, 0])

# %%
plt.figure(figsize=(5,5))
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.axis('equal')
plt.show()

# %%
def log_likelihood(theta):
    G = theta # unpack parameters from theta

    sol = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2)) # get solution of ODE with current choice of params
    
    return -np.sum((sol[:, 0] - y[:, 0])**2 + (sol[:, 2] - y[:, 2])**2) # normal distribution

# %%
D = 1  

prior_mu =  np.full((1,D), 10.0) # 
prior_std = 5 * np.ones((1, D)) # std of the prior

LB = np.full((1, D), 0.0)  # Lower bounds (we know from the model that they have to be positive, negative values would break odeint)
UB = np.full((1, D), 2000.0)  # Upper bounds (picked to be reasonable)

PLB =  scs.norm.ppf(0.1587, prior_mu, prior_std)
PUB =  scs.norm.ppf(0.8413, prior_mu, prior_std)

x0 = np.copy(prior_mu) # starting point for inference   # 1.5 * np.ones((1, D))

options = {
    "max_fun_evals": 300
}

vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = [scs.norm(loc = 10)], options = options) # initialize VMBC object

# %%
vp, results = vbmc.optimize();
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10         -18.56        29.01 809619647.10        2        inf     start warm-up
#      1         15          -3.41         0.02         9.56        2        inf
#      2         20          -3.43         0.00         0.00        2     0.0714
#      3         25          -3.43         0.00         0.00        2     0.0293
#      4         30          -3.44         0.00         0.00        2     0.0497
#      5         35          -3.45         0.00         0.00        2        0.2
#      6         40          -3.44         0.00         0.00        2      0.058     end warm-up
#      7         45          -3.44         0.00         0.01        2      0.323
#      8         50          -3.43         0.00         0.01        2      0.365
#      9         55          -3.44         0.00         0.01        5      0.222
#     10         60          -3.45         0.00         0.00        5       0.12
#     11         65          -3.43         0.00         0.00        5      0.158     stable
#    inf         65          -3.59         0.00         0.07       50      0.158     finalize
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -3.586 +/-0.001.

# %%
vp.plot();

# %%
# First, generate a large number of samples from the variational posterior:
n_samples = int(5e5)
Xs, _ = vp.sample(n_samples)

# Easily compute statistics such as moments, credible intervals, etc.
post_mean = np.mean(Xs, axis=0)  # Posterior mean
post_cov = np.cov(Xs.T)  # Posterior covariance matrix
print("The approximate posterior mean is:", post_mean)
#print("The approximate posterior covariance matrix is:\n", post_cov)
# Out:
# The approximate posterior mean is: [9.81047481]

# %% [markdown]
# This works really well!!
#
# however, increasing the time interval makes it converge not as well

# %%
G =  post_mean[0]

sol = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2))

plt.figure(figsize=(8,5))
#plt.title("Solution from Uniform Box Prior")
plt.plot(t,sol[:, 0], label = "predicted solution from BPE params")
plt.plot(t,y[:, 0], label = "true data")
plt.grid()
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()

# %%
# initial condition
th1 = 120.0
w1 = 0.0
th2 = -10.0
w2 = 0.0
initial_condition = np.radians([th1, w1, th2, w2])

# parameters
G = 9.8  # acceleration due to gravity, in m/s^2
L1 = 1.0  # length of pendulum 1 in m
L2 = 1.0  # length of pendulum 2 in m
M1 = 1.0  # mass of pendulum 1 in kg
M2 = 1.0  # mass of pendulum 2 in kg

# time setup
dt = 0.05
t = np.arange(0, 10, dt)

#integrate
y = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2))

def log_likelihood(theta):
    L1,L2 = theta # unpack parameters from theta

    sol = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2)) # get solution of ODE with current choice of params
    
    return -np.sum((sol[:, 0] - y[:, 0])**2 + (sol[:, 2] - y[:, 2])**2) # normal distribution

# %%
D = 2  

prior_mu =  np.full((1,D), 10.0) # 
prior_std = 5 * np.ones((1, D)) # std of the prior

LB = np.full((1, D), 0.0)  # Lower bounds (we know from the model that they have to be positive, negative values would break odeint)
UB = np.full((1, D), 2000.0)  # Upper bounds (picked to be reasonable)

PLB =  scs.norm.ppf(0.1587, prior_mu, prior_std)
PUB =  scs.norm.ppf(0.8413, prior_mu, prior_std)

x0 = np.copy(prior_mu) # starting point for inference   # 1.5 * np.ones((1, D))

options = {
    "max_fun_evals": 300
}

vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = UniformBox(LB,UB), options = options) # initialize VMBC object

# %%
vp, results = vbmc.optimize();
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10       -3407.30      1011.52 341897627.47        2        inf     start warm-up
#      1         15       -3440.21        43.39        25.79        2        inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 vp, results = vbmc.optimize();
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\vbmc.py:1094, in VBMC.optimize(self)
#    1087     else:
#    1088         self.optim_state["hyp_dict"] = self.hyp_dict
#    1089         (
#    1090             self.function_logger,
#    1091             self.optim_state,
#    1092             self.vp,
#    1093             self.gp,
# -> 1094         ) = active_sample(
#    1095             gp_search,
#    1096             new_funevals,
#    1097             self.optim_state,
#    1098             self.function_logger,
#    1099             self.iteration_history,
#    1100             self.vp,
#    1101             self.options,
#    1102         )
#    1103         self.hyp_dict = self.optim_state["hyp_dict"]
#    1105 # Number of training inputs
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\pyvbmc\vbmc\active_sample.py:398, in active_sample(gp, sample_count, optim_state, function_logger, iteration_history, vp, options)
#     389     insigma = np.sqrt(np.diag(Sigma))
#     390     cma_options = {
#     391         "verbose": -9,
#     392         "tolfun": tol_fun,
#    (...)
#     395         "seed": np.nan,
#     396     }
# --> 398     res = cma.fmin(
#     399         acq_fun,
#     400         x0,
#     401         np.max(insigma),
#     402         options=cma_options,
#     403         noise_handler=cma.NoiseHandler(np.size(x0)),
#     404     )
#     406     xsearch_optim, f_val_optim = res[:2]
#     407 elif options["search_optimizer"] == "Nelder-Mead":
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\evolution_strategy.py:4840, in fmin(objective_function, x0, sigma0, options, args, gradf, restarts, restart_from_best, incpopsize, eval_initial_x, parallel_objective, noise_handler, noise_change_sigma_exponent, noise_kappa_exponent, bipop, callback)
#    4836         if degrading_iterations_count > 4:
#    4837             utils.print_message('%d f-degrading iterations (set verbose<=4 to suppress)'
#    4838                                 % degrading_iterations_count,
#    4839                                 iteration=es.countiter)
# -> 4840 es.tell(X, fit)  # prepare for next iteration
#    4841 if noise_handling:  # it would be better to also use these f-evaluations in tell
#    4842     es.sigma *= noisehandler(X, fit, objective_function, es.ask,
#    4843                              args=args)**fmin_opts['noise_change_sigma_exponent']
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\evolution_strategy.py:3009, in CMAEvolutionStrategy.tell(self, solutions, function_values, check_points, copy)
#    3007         pop_zero_encoded = pop_zero / (self.sigma * self.sigma_vec.scaling)
#    3008         # pc is already good
# -> 3009     self.sm.update([(c1 / (c1a + 1e-23))**0.5 * self.pc] +  # c1a * pc**2 gets c1 * pc**2
#    3010                   list(pop_zero_encoded),
#    3011                   sampler_weights)
#    3012 if any(np.asarray(self.sm.variances) < 0):
#    3013     raise RuntimeError("A sampler variance has become negative "
#    3014                        "after the update, this must be considered as a bug.\n"
#    3015                        "Variances `self.sm.variances`=%s" % str(self.sm.variances))
#
# File c:\Users\walki\.conda\envs\bpe\Lib\site-packages\cma\sampler.py:347, in GaussFullSampler.update(self, vectors, weights, c1_times_delta_hsigma)
#     344     weights[k] *= len(vectors[k]) / (norm + 1e-9)**2
#     345     assert np.isfinite(weights[k])
# --> 347 self.C += np.dot(weights * vectors.T, vectors)
#     349 self.count_tell += 1
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
vp.plot();

# %%
# First, generate a large number of samples from the variational posterior:
n_samples = int(5e5)
Xs, _ = vp.sample(n_samples)

# Easily compute statistics such as moments, credible intervals, etc.
post_mean = np.mean(Xs, axis=0)  # Posterior mean
post_cov = np.cov(Xs.T)  # Posterior covariance matrix
print("The approximate posterior mean is:", post_mean)
#print("The approximate posterior covariance matrix is:\n", post_cov)
# Out:
# The approximate posterior mean is: [ 2.76330059 33.30369405]

# %%
L1 =  post_mean[0]
L2 = post_mean[1]

sol = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2))

plt.figure(figsize=(8,5))
#plt.title("Solution from Uniform Box Prior")
plt.plot(t,sol[:, 0], label = "predicted solution from BPE params")
plt.plot(t,y[:, 0], label = "true data")
plt.grid()
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
#plt.title("Solution from Uniform Box Prior")
plt.plot(t,sol[:, 1], label = "predicted solution from BPE params")
plt.plot(t,y[:, 1], label = "true data")
plt.grid()
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()

# %%
def log_likelihood(theta):
    G, L1, L2, M1, M2 = theta # unpack parameters from theta

    sol = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2)) # get solution of ODE with current choice of params
    
    return -np.sum((sol[:, 2] - y[:, 2])**2) # normal distribution

D = 5  

prior_mu =  np.full((1,D), 3.0)
prior_std = 1 * np.ones((1, D)) # std of the prior

LB = np.full((1, D), 0.0)  # Lower bounds (we know from the model that they have to be positive, negative values would break odeint)
UB = np.full((1, D), 5.0)  # Upper bounds (picked to be reasonable)
UB[0][0] = 20

PLB =  np.full((1, D), 0.5) #scs.norm.ppf(0.1587, prior_mu, prior_std)
PUB =  np.full((1, D), 2.0) #scs.norm.ppf(0.8413, prior_mu, prior_std)
PLB[0][0] = 8
PUB[0][0] = 11
x0 = np.copy(PLB) + 0.5 # starting point for inference   # 1.5 * np.ones((1, D))

options = {
    "max_fun_evals": 150
}

vbmc = VBMC(log_likelihood, x0, LB, UB, PLB, PUB, prior = [scs.norm(loc = 10),scs.norm(loc = 1),scs.norm(loc = 1),scs.norm(loc = 1),scs.norm(loc = 1)], options = options) # initialize VMBC object

# %%
vp, results = vbmc.optimize();
# Out:
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10        -679.97       876.85 77946955252.07        2        inf     start warm-up
#      1         15          75.16       152.58       185.74        2        inf
#      2         20          79.91       404.16      1184.43        2    1.9e+04
#      3         25        3756.65      6204.18      9836.72        2    1.8e+05
#      4         30   284695779.12 721139146.35 43587716476109.55        2    6.5e+14     trim data
#      5         35         135.93       826.09 80604929026204.47        2    1.2e+15
#      6         40        7242.36      4522.97     45427.20        2   7.16e+05     end warm-up
#      7         45          48.30        92.47     56991.72        2   8.74e+05
#      8         50         341.38      1081.15      2384.35        2   4.01e+04
#      9         55        2910.88      3766.41      2599.57        3   5.99e+04
#     10         60        1157.82      4127.80     39525.82        3   6.09e+05
#     11         65        2712.23      4971.89      1735.29        3   4.76e+04
#     12         70         782.81      4030.94      2641.02        3   5.92e+04
#     13         75         250.95       937.93       993.83        3   1.97e+04
#     14         80          25.00       179.85       519.04        4   9.09e+03
#     15         85        3628.13      7824.80     11158.48        5   2.04e+05
#     16         90        3173.89      4749.60      5209.89        5    9.5e+04
#     17         95         642.63      2684.42      5866.68        5   1.05e+05
#     18        100         148.52       317.16      3469.26        5   5.44e+04
#     19        105        3696.18      5399.21      7963.82        6   1.49e+05
#     20        110          13.17      1890.80      2131.23        6   5.03e+04
#     21        115         443.12       804.62      1011.56        6   1.92e+04
#     22        120        1031.31       623.66      2847.99        6   4.65e+04
#     23        125        1419.61      1320.52    153400.26        7   2.29e+06
#     24        130        1169.93      1354.26      1922.07        7    3.4e+04
#     25        135        1786.91      2964.98      2782.27        7   5.34e+04
#     26        140        1423.69      1648.90      2595.70        7   4.54e+04
#     27        145         171.82       415.65       780.15        7   1.72e+04
#     28        150        1764.85      2976.74      3115.11        8   6.17e+04
#    inf        150        2043.32      3961.64      1128.37       50   1.72e+04     finalize
# Inference terminated: reached maximum number of function evaluations options.max_fun_evals.
# Estimated ELBO: 2043.316 +/-3961.637.
# Caution: Returned variational solution may have not converged.

# %%
vp.plot();

# %%
# First, generate a large number of samples from the variational posterior:
n_samples = int(5e5)
Xs, _ = vp.sample(n_samples)

# Easily compute statistics such as moments, credible intervals, etc.
post_mean = np.mean(Xs, axis=0)  # Posterior mean
post_cov = np.cov(Xs.T)  # Posterior covariance matrix
print("The approximate posterior mean is:", post_mean)
#print("The approximate posterior covariance matrix is:\n", post_cov)
# Out:
# The approximate posterior mean is: [19.91846502  0.98187058  1.68430873  4.99635742  3.02052359]

# %%
G,L1,L2,M1,M2 =  [post_mean[i] for i in range(5)]

sol = odeint(diffyqs, initial_condition, t, args = (G,L1,L2,M1,M2))

plt.figure(figsize=(8,5))
#plt.title("Solution from Uniform Box Prior")
plt.plot(t,sol[:, 0], label = "predicted solution from BPE params")
plt.plot(t,y[:, 0], label = "true data")
plt.grid()
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()
