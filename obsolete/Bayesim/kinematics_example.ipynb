# %% [markdown]
# This is from Rachel, it's for the bayesim thing. IT HAS NOT BEEN USED SINCE THE FIRST WEEK.

# %% [markdown]
# # Kinematics Example
# Start by importing all the code we'll need.

# %%
import numpy as np
import sys
import math
import pandas as pd
sys.path.append('../../')
import bayesim.model as bym
import bayesim.params as byp
import deepdish as dd
import matplotlib.pyplot as plt
#from jupyterthemes import jtplot
#jtplot.style('default')
np.random.seed(0)

# %% [markdown]
# First, we define our model function, in this case a simple parabolic trajectory for a projectile:
# $$y(t) = v_0t-\frac12gt^2$$

# %%
def model_y(ec, params):
    """
    Simple model of a kinematic trajectory.
    Args:
        ec (`dict`): dictionary with a key 't' leading to a float value
        params (`dict`): dictionary with keys 'v0' and 'g' leading to float values
    Returns:
        float: y-value at the given time assuming the given parameters
    """
    # read in the inputs
    t = ec['t'] # experimental conditions
    v0 = params['v0']
    g = params['g']

    # compute and return
    return v0*t - 0.5 * g * t**2

# %% [markdown]
# Next, define the parameters to be fit.

# %%
pl = byp.Param_list()
pl.add_fit_param(name='v0', val_range=[0,20], units='m/s', display_name='$v_0$')
pl.add_fit_param(name='g', val_range=[0,20], units='m/s$^2$')
pl.add_ec(name='t', units='s', is_x=True) # plot this on the x-axis
pl.add_output(name='y', units='m')

# %% [markdown]
# Suppose we measure two data points: At time $t=2$, a height of $3.1\pm0.2$ m, and at time $t=2.3$, a height of $0.1\pm0.5 m$.

# %%
# the first two "observations"
data = pd.DataFrame()
data['t'] = [2, 2.3]
data['y'] = [3.1, 0.1]
data['uncertainty'] = [0.2, 0.5]
dd.io.save('two_points.h5', data)

# %% [markdown]
# We create the model object using our parameters and attach the observed data as well as the model function.

# %%
m = bym.Model(params=pl, obs_data_path='two_points.h5', model_data_func=model_y, calc_model_unc=True, keep_all=True)
m.run()
# Out:
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# Used all the observed data! Last PMF to go into average may have been further from threshold condition.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 m = bym.Model(params=pl, obs_data_path='two_points.h5', model_data_func=model_y, calc_model_unc=True, keep_all=True)
# ----> 2 m.run()
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:786, in Model.run(self, **argv)
#     784 probs_lists.append(np.array(self.probs.points['prob']))
#     785 if save_step >= 0:
# --> 786     dd.save(pmf_folder+'sub%d_run%d_PMF_final.h5'%(self.probs.num_sub,num_runs),self.probs.points)
#     787 at_threshold=True
#     788 dd.save(obs_list_folder+'sub%d_run%d_obs_list.h5'%(self.probs.num_sub,num_runs),self.obs_data.iloc[obs_indices])
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:598, in save(path, data, compression)
#     594         _save_level(h5file, group, value, name=key,
#     595                     filters=filters, idtable=idtable)
#     597 else:
# --> 598     _save_level(h5file, group, data, name='data',
#     599                 filters=filters, idtable=idtable)
#     600     # Mark this to automatically unpack when loaded
#     601     group._v_attrs[DEEPDISH_IO_UNPACK] = True
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:254, in _save_level(handler, group, level, name, filters, idtable)
#     251 elif isinstance(level, np.ndarray):
#     252     _save_ndarray(handler, group, name, level, filters=filters)
# --> 254 elif _pandas and isinstance(level, (pd.DataFrame, pd.Series, pd.Panel)):
#     255     store = _HDFStoreWithHandle(handler)
#     256     store.put(group._v_pathname + '/' + name, level)
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
m.visualize_probs()

# %% [markdown]
# Suppose we generate a larger set of "noisy observations" over a broader range of times.

# %%
params = {'v0':11.31,'g':9.81}
data = pd.DataFrame()
t_vals = np.arange(0,3,0.1)
y_vals = [model_y({'t':t}, params)+0.3*np.random.randn() for t in t_vals]
data['t'] = t_vals
data['y'] = y_vals
dd.io.save('obs_data.h5',data)

# %%
plt.plot(t_vals, y_vals)
plt.xlabel('time [s]')
plt.ylabel('height [m]')
plt.show()

# %%
# initialize bayesim model object again, now with more data (and assuming the larger uncertainty value for all the points)
m = bym.Model(params=pl, obs_data_path='obs_data.h5', model_data_func=model_y, calc_model_unc=True, fixed_unc=0.5, keep_all=True)

# run, using all data points
m.run(min_num_pts=len(m.obs_data))
# Out:
# done, points so far: 5
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       2 m = bym.Model(params=pl, obs_data_path='obs_data.h5', model_data_func=model_y, calc_model_unc=True, fixed_unc=0.5, keep_all=True)
#       4 # run, using all data points
# ----> 5 m.run(min_num_pts=len(m.obs_data))
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:786, in Model.run(self, **argv)
#     784 probs_lists.append(np.array(self.probs.points['prob']))
#     785 if save_step >= 0:
# --> 786     dd.save(pmf_folder+'sub%d_run%d_PMF_final.h5'%(self.probs.num_sub,num_runs),self.probs.points)
#     787 at_threshold=True
#     788 dd.save(obs_list_folder+'sub%d_run%d_obs_list.h5'%(self.probs.num_sub,num_runs),self.obs_data.iloc[obs_indices])
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:598, in save(path, data, compression)
#     594         _save_level(h5file, group, value, name=key,
#     595                     filters=filters, idtable=idtable)
#     597 else:
# --> 598     _save_level(h5file, group, data, name='data',
#     599                 filters=filters, idtable=idtable)
#     600     # Mark this to automatically unpack when loaded
#     601     group._v_attrs[DEEPDISH_IO_UNPACK] = True
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:254, in _save_level(handler, group, level, name, filters, idtable)
#     251 elif isinstance(level, np.ndarray):
#     252     _save_ndarray(handler, group, name, level, filters=filters)
# --> 254 elif _pandas and isinstance(level, (pd.DataFrame, pd.Series, pd.Panel)):
#     255     store = _HDFStoreWithHandle(handler)
#     256     store.put(group._v_pathname + '/' + name, level)
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
m.visualize_probs(true_vals=params)

# %%
m.comparison_plot()

# %% [markdown]
# And now we subdivide the grid!

# %%
m.subdivide()
# Out:
# 8 box(es) with probability > 0.01 and 15 neighboring boxes subdivided!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 m.subdivide()
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:827, in Model.subdivide(self, **argv)
#     825 self.is_run = False
#     826 #dd.save(filename,new_boxes)
# --> 827 self.list_model_pts_to_run(fpath=filename)
#     828 print('New model points to simulate are saved in the file %s.'%filename)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:856, in Model.list_model_pts_to_run(self, fpath, **argv)
#     854         pts.append(list(ppt[1])+list(ecpt[1]))
#     855 sim_pts = pd.DataFrame(data=pts,columns=columns)
# --> 856 dd.save(fpath,sim_pts)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:598, in save(path, data, compression)
#     594         _save_level(h5file, group, value, name=key,
#     595                     filters=filters, idtable=idtable)
#     597 else:
# --> 598     _save_level(h5file, group, data, name='data',
#     599                 filters=filters, idtable=idtable)
#     600     # Mark this to automatically unpack when loaded
#     601     group._v_attrs[DEEPDISH_IO_UNPACK] = True
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:254, in _save_level(handler, group, level, name, filters, idtable)
#     251 elif isinstance(level, np.ndarray):
#     252     _save_ndarray(handler, group, name, level, filters=filters)
# --> 254 elif _pandas and isinstance(level, (pd.DataFrame, pd.Series, pd.Panel)):
#     255     store = _HDFStoreWithHandle(handler)
#     256     store.put(group._v_pathname + '/' + name, level)
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
m.attach_model(mode='function', model_data_func=model_y, calc_model_unc=True)

# %%
m.run(min_num_pts=len(m.obs_data))
# Out:
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# /Users/gracerojo/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:758: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   ecpt = float(ec)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 m.run(min_num_pts=len(m.obs_data))
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:776, in Model.run(self, **argv)
#     774 # save intermediate PMF if necessary
#     775 if save_step >0 and (num_pts_used-prev_used_pts) % save_step == 0:
# --> 776     dd.save(pmf_folder+'sub%d_run%d_PMF_%d.h5'%(self.probs.num_sub,num_runs,num_pts_used-prev_used_pts),self.probs.points)
#     778 # check if threshold probability concentration has been reached
#     779 if np.sum(self.probs.most_probable(int(th_pv*len(self.probs.points)))['prob'])>th_pm:
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:598, in save(path, data, compression)
#     594         _save_level(h5file, group, value, name=key,
#     595                     filters=filters, idtable=idtable)
#     597 else:
# --> 598     _save_level(h5file, group, data, name='data',
#     599                 filters=filters, idtable=idtable)
#     600     # Mark this to automatically unpack when loaded
#     601     group._v_attrs[DEEPDISH_IO_UNPACK] = True
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:254, in _save_level(handler, group, level, name, filters, idtable)
#     251 elif isinstance(level, np.ndarray):
#     252     _save_ndarray(handler, group, name, level, filters=filters)
# --> 254 elif _pandas and isinstance(level, (pd.DataFrame, pd.Series, pd.Panel)):
#     255     store = _HDFStoreWithHandle(handler)
#     256     store.put(group._v_pathname + '/' + name, level)
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
m.visualize_probs(true_vals=params)

# %%
m.comparison_plot()

# %%
m.subdivide()
m.attach_model(mode='function', model_data_func=model_y, calc_model_unc=True)
m.run(min_num_pts=len(m.obs_data))
m.visualize_probs(true_vals=params)
# Out:
# 80 box(es) with probability > 0.004310344827586207 and 52 neighboring boxes subdivided!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 m.subdivide()
#       2 m.attach_model(mode='function', model_data_func=model_y, calc_model_unc=True)
#       3 m.run(min_num_pts=len(m.obs_data))
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:827, in Model.subdivide(self, **argv)
#     825 self.is_run = False
#     826 #dd.save(filename,new_boxes)
# --> 827 self.list_model_pts_to_run(fpath=filename)
#     828 print('New model points to simulate are saved in the file %s.'%filename)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:856, in Model.list_model_pts_to_run(self, fpath, **argv)
#     854         pts.append(list(ppt[1])+list(ecpt[1]))
#     855 sim_pts = pd.DataFrame(data=pts,columns=columns)
# --> 856 dd.save(fpath,sim_pts)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:598, in save(path, data, compression)
#     594         _save_level(h5file, group, value, name=key,
#     595                     filters=filters, idtable=idtable)
#     597 else:
# --> 598     _save_level(h5file, group, data, name='data',
#     599                 filters=filters, idtable=idtable)
#     600     # Mark this to automatically unpack when loaded
#     601     group._v_attrs[DEEPDISH_IO_UNPACK] = True
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:254, in _save_level(handler, group, level, name, filters, idtable)
#     251 elif isinstance(level, np.ndarray):
#     252     _save_ndarray(handler, group, name, level, filters=filters)
# --> 254 elif _pandas and isinstance(level, (pd.DataFrame, pd.Series, pd.Panel)):
#     255     store = _HDFStoreWithHandle(handler)
#     256     store.put(group._v_pathname + '/' + name, level)
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
m.comparison_plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 m.comparison_plot()
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:615, in Model.comparison_plot(self, **argv)
#     613 for pt in param_pts.iterrows():
#     614     color = colors[c_ind]
# --> 615     model_data = deepcopy(self.model_data.loc[self.model_data_grps.groups[tuple([pt[1][n] for n in self.fit_param_names()])]])
#     616     if not one_ec:
#     617         # get modeled data just at these conditions
#     618         for c in other_ecs:
#
# KeyError: (10.56, 8.06)

# %%
m.subdivide()
m.attach_model(mode='function', model_data_func=model_y, calc_model_unc=True)
m.run(min_num_pts=len(m.obs_data))
m.visualize_probs(true_vals=params)
# Out:
# 28 box(es) with probability > 0.010869565217391304 and 30 neighboring boxes subdivided!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 m.subdivide()
#       2 m.attach_model(mode='function', model_data_func=model_y, calc_model_unc=True)
#       3 m.run(min_num_pts=len(m.obs_data))
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:827, in Model.subdivide(self, **argv)
#     825 self.is_run = False
#     826 #dd.save(filename,new_boxes)
# --> 827 self.list_model_pts_to_run(fpath=filename)
#     828 print('New model points to simulate are saved in the file %s.'%filename)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:856, in Model.list_model_pts_to_run(self, fpath, **argv)
#     854         pts.append(list(ppt[1])+list(ecpt[1]))
#     855 sim_pts = pd.DataFrame(data=pts,columns=columns)
# --> 856 dd.save(fpath,sim_pts)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:598, in save(path, data, compression)
#     594         _save_level(h5file, group, value, name=key,
#     595                     filters=filters, idtable=idtable)
#     597 else:
# --> 598     _save_level(h5file, group, data, name='data',
#     599                 filters=filters, idtable=idtable)
#     600     # Mark this to automatically unpack when loaded
#     601     group._v_attrs[DEEPDISH_IO_UNPACK] = True
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/hdf5io.py:254, in _save_level(handler, group, level, name, filters, idtable)
#     251 elif isinstance(level, np.ndarray):
#     252     _save_ndarray(handler, group, name, level, filters=filters)
# --> 254 elif _pandas and isinstance(level, (pd.DataFrame, pd.Series, pd.Panel)):
#     255     store = _HDFStoreWithHandle(handler)
#     256     store.put(group._v_pathname + '/' + name, level)
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
m.comparison_plot(num_param_pts=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 m.comparison_plot(num_param_pts=3)
#
# File ~/opt/anaconda3/envs/bpe/lib/python3.11/site-packages/bayesim/model.py:615, in Model.comparison_plot(self, **argv)
#     613 for pt in param_pts.iterrows():
#     614     color = colors[c_ind]
# --> 615     model_data = deepcopy(self.model_data.loc[self.model_data_grps.groups[tuple([pt[1][n] for n in self.fit_param_names()])]])
#     616     if not one_ec:
#     617         # get modeled data just at these conditions
#     618         for c in other_ecs:
#
# KeyError: (10.12, 8.38)
